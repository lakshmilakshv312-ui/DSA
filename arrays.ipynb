# %%
# findding sum of array elements
def count_sum(arr):
    total = 0
    for num in arr:
        total += num 
    return total
arr = [1,2,3,4,5]
print("sum:", count_sum(arr))
# Out:
# sum: 15

# %%
# counting the digits in array
def count_digits(arr):
    total = 0
    for num in arr:
        total += 1
    return total
arr = [1,2,3,4,5,6]
print("digits:", count_digits(arr))
# Out:
# digits: 6

# %%
# counting the even digits
def even_digits(arr):
    total = 0
    for i in arr:
        if i % 2 == 0:
            total += 1
    return total
arr = [1,2,3,4,5,6]
print("even_digits:", even_digits(arr))
# Out:
# even_digits: 3

# %%
# finding max value in array
def count_sum(arr):
    total = 0
    for num in arr:
        total += num
    return total
arr = [1,2,3,4,5,10]
print(max(arr))
# Out:
# 10

# %%
# finding max value in array
def count_sum(arr):
    pass
count_sum(arr)
arr = [1,2,3,4,5,10]
print(max(arr))
# Out:
# 10

# %%
# finding max value in array
arr = [1,2,3,4,5,10]
print(max(arr))
# Out:
# 10

# %%
# file handling expenses tracking system

expenses = []
def export_expenses(expenses):
    with open("expenses.txt","w") as file:
        for expense in expenses:
            file.write(expense["name"] + " " + expense["amount"] + "/n")
def main():
    while True:
        print("/n1. add expense")
        print("/n2. view expenses")
        print("/n3. export to file")
        print("4. exit")

        choice = input("enter choice:")

        if choice == "1":
            name = input("enter expense name:")
            amount = input("enter amount:")

            expenses.append({"name": name, "amount": amount})
        elif choice == "2":
            for expense in expenses:
                print(expense["name"],"-",expense["amount"])

        elif choice == "3":
            export_expenses(expenses)
        elif choice == "4":
            print("exiting the program")
            break
        else:
            print("invalid choice , try again")
main()
# Out:
# /n1. add expense
# /n2. view expenses
# /n3. export to file
# 4. exit
# enter choice: 1
# enter expense name: food
# enter amount: 200
# /n1. add expense
# /n2. view expenses
# /n3. export to file
# 4. exit
# enter choice: 1
# enter expense name: travel
# enter amount: 1000
# /n1. add expense
# /n2. view expenses
# /n3. export to file
# 4. exit
# enter choice: 1
# enter expense name: metro
# enter amount: 500
# /n1. add expense
# /n2. view expenses
# /n3. export to file
# 4. exit
# enter choice: 2
# food - 200
# travel - 1000
# metro - 500
# /n1. add expense
# /n2. view expenses
# /n3. export to file
# 4. exit
# enter choice: 3
# /n1. add expense
# /n2. view expenses
# /n3. export to file
# 4. exit
# enter choice: 4
# exiting the program
